# %%
] activate ../../Acceleration
# Out:
#  Activating environment at `~/Desktop/Code/Acceleration/Acceleration/Project.toml`

# %%
using Acceleration
using LinearAlgebra

n = 1000; # number of samples
d = 50;    # number of features
selected_labels = [0,1];  ## Only two labels allowed

data, labels = load_dataset("FashionMNIST",[0,1],n,d);
f,∇f,∇ϕ_cjg,σ,L,μ  = linear_regression(data,labels);
μ2 = μ;
# Out:
# ┌ Info: Loading dataset MNIST with 60000 samples and 784 features
# └ @ Acceleration /Users/victor/Desktop/Code/Acceleration/Acceleration/src/datasets.jl:26

# %%
n = size(data,2)
x_ini = zeros(n)

using JuMP
using Ipopt

@time model = Model(with_optimizer(Ipopt.Optimizer))
@time set_silent(model)
@time @variable(model, x[1:n])
@time @objective(model, Min, f(x))
@time optimize!(model)
@time x_opt = value.(x);
# Out:
#   0.000175 seconds (652 allocations: 36.172 KiB)
#   0.000005 seconds
#   0.028023 seconds (63.87 k allocations: 3.335 MiB)
#   0.082304 seconds (22.77 k allocations: 52.967 MiB)
#   0.012260 seconds (911 allocations: 173.641 KiB)
#   0.000109 seconds (603 allocations: 12.234 KiB)

# %%
n = length(x_ini)
x = x_ini;
y = zeros(n);
z = zeros(n);
v = zeros(n);
A0 = σ/(2*L);
A = A0;
AX = zeros(n);

k = 1000;
yks = zeros(n,k);
var_ξ = zeros(k)
#μ = 0;
s = zeros(n);
p = 1
ξ = 0;
w = 0;
p = 0.5;

for i=1:k   
    if(ξ > 0)
        p = p +1000;
    end
    λ = min((L/μ)*(p/i)^2, 1)
    #λ = min((p+1)*(i+1)^(p-1),1)
    a = L-μ; b = -λ*(μ*A + σ); c = -λ*(μ*A^2 + σ*A);
    α = (-b + sqrt(b^2 - 4*a*c)) / (2*a);
    A = A + α;
    x = (A-α)/A*y + α/A*v; 
    AX = AX + α*x;

    η = zeros(n)
    approx_gradient = ∇f(x)+η;
    
    s = s + α*η;
    z = z - α*approx_gradient;
    
    v_past = v;
    v = (z + μ*AX)*inv(1 + μ*(A-A0));
    y = (A-α)*inv(A)*y + α*inv(A)*v; 
    ξ = sqrt(1-λ)*(μ*(A-α) + σ)/α * norm(v-v_past,2);
    var_ξ[i] = ξ;
      
    yks[:,i] = y;
        
end

x_out = yks;
p_out = sqrt.(sum((x_out .- x_opt).^2, dims=1)');

#=>
filename = string("logs/",p,".txt")
io = open(filename, "w")
for i=1:k
    print(io,i)
    print(io,"\t")
    print(io, p_out[i])
    print(io,"\t")
    println(io, var_ξ[i])
end
close(io)
<=#

# %%
using Plots
using LinearAlgebra

p_out = sqrt.(sum((x_out .- x_opt).^2, dims=1)');

plot(max.(hcat(p_out,var_ξ),1e-5),yaxis=:log,linewidth=2,xlabel="training rounds",ylabel="loss")
#plot(max.(hcat(p_out),1e-20),yaxis=:log)

# %%
p
# Out:
# 51.60000000000046
